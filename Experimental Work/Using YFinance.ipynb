# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_datareader
import datetime
import pandas_datareader.data as web
import os
import sys
import glob
import yfinance as yf
from pandas_datareader import data as pdr

# %%
df=pdr.get_data_yahoo(["MMM","GOOG"],start="2013-01-01", end="2019-12-31")

# %%
df
# Out:
# Attributes   Adj Close                    Close                     High  \
# Symbols            MMM         GOOG         MMM         GOOG         MMM
# Date
# 2012-12-31   77.463661   352.369232   92.849998   352.369232   92.919998
# 2013-01-02   79.073837   360.274597   94.779999   360.274597   94.790001
# 2013-01-03   78.982063   360.483826   94.669998   360.483826   94.930000
# 2013-01-04   79.566071   367.607117   95.370003   367.607117   95.480003
# 2013-01-07   79.666168   366.003143   95.489998   366.003143   95.730003
# ...                ...          ...         ...          ...         ...
# 2019-12-24  176.679993  1343.560059  176.679993  1343.560059  178.669998
# 2019-12-26  176.589996  1360.400024  176.589996  1360.400024  176.660004
# 2019-12-27  177.259995  1351.890015  177.259995  1351.890015  177.539993
# 2019-12-30  175.830002  1336.140015  175.830002  1336.140015  178.960007
# 2019-12-31  176.419998  1337.020020  176.419998  1337.020020  176.589996
#
# ...

# %%
os.chdir("/home/ronet/Desktop/Capstone-Revised/")
with open('snp500_formatted.txt','r') as f:
    data=f.read()
data=data.split('\n')
all_filenames=data

# %%
all_filenames
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'AYI',
#  'ADBE',
#  'AAP',
#  'AES',
#  'AET',
#  'AMG',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'AA',
#  'ALXN',
#  'ALLE',
#  'AGN',
#  'ADS',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'APC',
#  'ADI',
#  'ANTM',
#  'AON',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'ADM',
#  'AJG',
#  'AIZ',
#  'T',
#  'ADSK',
#  'ADP',
#  'AN',
#  'AZO',
#  'AVGO',
#  'AVB',
#  'AVY',
#  'BHI',
#  'BLL',
#  'BAC',
#  'BCR',
#  'BAX',
#  'BBT',
#  'BDX',
#  'BBBY',
#  'BRK-B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'HRB',
#  'BA',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'BF-B',
#  'CHRW',
#  'CA',
#  'COG',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBG',
#  'CBS',
#  'CELG',
#  'CNC',
#  'CNP',
#  'CTL',
#  'CERN',
#  'CF',
#  'SCHW',
#  'CHK',
#  'CVX',
# ...

# %%
joint_csv=pd.DataFrame()

for f in all_filenames:
    df=pdr.get_data_yahoo(f, start=datetime.datetime(2013,1,1), end=datetime.datetime(2019,12,31))
    df['Stock_Name']=f
    joint_csv=pd.concat([joint_csv,df])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-cf9c00d9cfcb> in <module>
#       2
#       3 for f in all_filenames:
# ...
