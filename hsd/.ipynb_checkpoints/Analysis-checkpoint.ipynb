# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import csv
import os
import glob
import matplotlib.dates as mdates
# %matplotlib inline

# %%
os.chdir("/home/ronet/Desktop/strtsmrt-master/data/hsd")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
joint_csv=pd.DataFrame()
for f in all_filenames:
    df=pd.read_csv(f)
    df['Stock_Name']=f[:-4]
    joint_csv=pd.concat([joint_csv,df])

joint_csv.to_csv("stocks_trend.csv", index=False, encoding='utf-8-sig')

# %%
joint_csv
# Out:
#             Date       Open       High        Low      Close   Volume  \
# 0     2017-02-13  78.949997  79.639999  78.809998  79.610001  1427500
# 1     2017-02-10  78.550003  79.309998  78.129997  78.879997  1636700
# 2     2017-02-09  77.989998  78.389999  77.730003  78.349998  1910500
# 3     2017-02-08  78.099998  78.190002  77.800003  77.989998  1496600
# 4     2017-02-07  78.500000  78.680000  78.070000  78.120003  1762400
# ...          ...        ...        ...        ...        ...      ...
# 1032  2013-01-08  55.750000  55.790001  54.820000  55.410000  3370800
# 1033  2013-01-07  55.619999  55.939999  55.099998  55.840000  4536200
# 1034  2013-01-04  54.160000  55.040001  54.099998  55.020000  2371200
# 1035  2013-01-03  53.599998  54.700001  53.320000  54.200001  3887600
# 1036  2013-01-02  54.130001  54.130001  53.060001  53.709999  5446900
#
#       Adj Close Stock_Name
# 0     79.610001        ALL
# 1     78.879997        ALL
# 2     78.349998        ALL
# ...

# %%
names=joint_csv['Stock_Name'].unique()

# %%
any(joint_csv.isna())
# Out:
# True

# %%
stocks_df=pd.read_csv("stocks_trend.csv")

# %%
stocks_df.head()
# Out:
#          Date       Open       High        Low      Close   Volume  Adj Close  \
# 0  2017-02-13  78.949997  79.639999  78.809998  79.610001  1427500  79.610001
# 1  2017-02-10  78.550003  79.309998  78.129997  78.879997  1636700  78.879997
# 2  2017-02-09  77.989998  78.389999  77.730003  78.349998  1910500  78.349998
# 3  2017-02-08  78.099998  78.190002  77.800003  77.989998  1496600  77.989998
# 4  2017-02-07  78.500000  78.680000  78.070000  78.120003  1762400  78.120003
#
#   Stock_Name
# 0        ALL
# 1        ALL
# 2        ALL
# 3        ALL
# 4        ALL

# %%
for stock in stocks_df['Stock_Name'].unique():
    subset=stocks_df[['Stock_Name']==stock]

# %%
subs_ALL=stocks_df.loc[stocks_df['Stock_Name']=='ALL']
subs_ALL
# Out:
#             Date       Open       High        Low      Close   Volume  \
# 0     2017-02-13  78.949997  79.639999  78.809998  79.610001  1427500
# 1     2017-02-10  78.550003  79.309998  78.129997  78.879997  1636700
# 2     2017-02-09  77.989998  78.389999  77.730003  78.349998  1910500
# 3     2017-02-08  78.099998  78.190002  77.800003  77.989998  1496600
# 4     2017-02-07  78.500000  78.680000  78.070000  78.120003  1762400
# ...          ...        ...        ...        ...        ...      ...
# 1032  2013-01-08  41.619999  41.830002  41.470001  41.830002  2406500
# 1033  2013-01-07  42.070000  42.099998  41.480000  41.740002  2250600
# 1034  2013-01-04  41.590000  42.360001  41.450001  42.200001  3019200
# 1035  2013-01-03  41.200001  41.630001  40.950001  41.580002  2794600
# 1036  2013-01-02  40.900002  41.169998  40.650002  41.160000  3176100
#
#       Adj Close Stock_Name
# 0     79.610001        ALL
# 1     78.879997        ALL
# 2     78.349998        ALL
# ...

# %%
x=np.array(subs_ALL['Date'], dtype='datetime64')
y=np.array(subs_ALL['Volume'])
fig, ax=plt.subplots()
ax.plot(x,y)

myFmt = mdates.DateFormatter('%m\%y')

ax.xaxis.set_major_formatter(myFmt)
fig.autofmt_xdate()
plt.show()

# %%
for i in x:
    if(i==0):
        print(i)
